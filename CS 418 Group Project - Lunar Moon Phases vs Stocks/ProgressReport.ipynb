# %% [markdown]
# # Progress Report
#
# CS418 Data Science
#
# 04/05/2024
#
# - Bart Nowobilski
# - Emilio Kiryakos
# - David Mendoza
# - Adithya Jose
# - Mustafa Ausaf

# %% [markdown]
# **Introduction:**
# ___________________________________________________________________________________________________
# The question were are investigating is whether a correlation exists between
# the lunar phases and the behavior of stocks. In the world of finance, traders and analysis,
# have aimed to uncover any patterns and trends that may aid in making financial decisions in this
# case stock investments. Since ancient times it is believed that celestial events have had an
# impacted on animals, humans, and their activity and behavior. We understand we have to be mindful
# of correlation without causation but this is an intresting stragetgy that many people employ already
# and we seek to support or deny the validity of this stragetgy. Using historical stock data and collected
# phases of the moon ranging years back we seek to examine patterns and statistics that could easily
# elude the naked eye. More specifically we're investigating a few areas of stock behavior including the
# relationship between the phases of the moon and volume, the avg price increase between phases,
# the highs and lows of price within a lunar cycle, and more. This project is not motivated by just
# academic curiosity, it also holds practical uses providing another source of information to make
# educated financial decisions.

# %% [markdown]
# **Changes since the proposal:**
# __________________________________________________________________________________________________
# Since our proposal we have made some changes/updates to our inital proposed plan. After collecting
# our data and seeing the avaible information collected we were able to further defined the
# scope of our research and analysis.
# - Initially we proposed to investigating soley the relationship between the phases of the moon and price action of a stock
# - Realizing the avaiblilty of the data we had we added exploration of different areas of stock related info to provide insightful findings
# and idenify other potential consistencies. As previously mentioned were taking a look at the stock price for the day open and close, the days high
# and the lows, and the volume of stock each day

# %% [markdown]
# **Data:**
# _______________________________________________________________________________________________________________________
# The data we have collected came from the use of API Polygio.IO and DateAndTime which gave us a limited amount of free data.
# With the restrictions on amount of data we could collect we gathered stock info and lunar phase data dating back to March of 2019
# We stored data in csv files for easy access and compatability.
# - Lunar Data includes: Date and Moon Phase
# - Stock Data includes:open, high, low, close, volume, vwap, timestamp, transactions
#
# We collected this data for 5 stocks: Apple, Nasdaq, Nvidia, Spy, and Tesla
#
# Then we chose a time frame to look at starting at 01-01-2020 to 01-01-2024 to have a clean time frame to investigate
# we removed any dates not within our desired data set and we then merged our moon phase data with our stock data on
# date to have a dataframe with the relevant stock and lunar data for a given date. This allowed us to get stared on exploring
# and analyzing our data

# %% [markdown]
# **Exploratory Data analysis:**
# ________________________________________________________________________________________________________________
# ![figure1_Bart.png](attachment:figure1_Bart.png)
#
# What this first set of plots show us are the periods of lunar cyles starting at new moons to a full moon. Each cycle
# is colored in red or green indicating a positive percent change or negative percent change in price. After looking at
# the moon cycles for the last four years we made some intresting observations. If an individual were to put in $1000 at each
# new moon and sell at each full moon how ofter would they make money and how much return would that make.
# - Apple: 61.22% positive percent change, $548.22 made after four years
# - Nasdaq: 59.18% positive percent change, $408.97 made after four years
# - Nvidia: 57.14% positive percent change, $828.56 made after four years
# - Spy: 59.18% positive percent change, $190.28 made after four years
# - Tesla: 44.90% positive percent change, $861.46 made after four years
# These results are intriguing because just using this stragegy in the last 4 years would have made an investor decent returns.
# Looking at these percentages, about 56% of lunar cycles had positive returns. Taking this into account we want to look
# at a greater set of stocks to see consistencies, also look at individual years that could inconsistency due to financial
# crisises. (Bart Nowobilski)

# %% [markdown]
# **Visualizations & Hypotheses:**
# ________________________________________________________________________________________________________________
# At least five visualizations that shows an interesting hypothesis, along with an
# explanation about why you thought this was an interesting hypothesis to
# Investigate. Write the name of the member(s) who is responsible for each of them while
# explaining it.

# %% [markdown]
# ![Stock Volume vs Moon Phases](../LunarPhaseStockExploration/visualizations/emilio_plots.png)
# The image above visualizes the stock volume of all 5 stocks and the moon phases sequence over time within the past 5 years along. The stock volume for all 5 are consistently very volatile.
#
# ![Stock Volume vs Moon Phases](../LunarPhaseStockExploration/visualizations/emilio_plots_2.png)
# The image above visualizes the correlation between stock volumes to the new moon, full moon and to all moon phases with cross-correlation line graphs. The correlation graphs visualizes that there is usually a strong negative correlation. In the cross-correlation graphs, the lag represents shifting over time from the middle of the data which is the mid point of the 5 years of data where +10 is the first day and -10 is the most recent date retrieved
#
# Overall, this shows that most stocks seem to have strong negative correlation in most moon phases except at full moon with the exception of the SPY stock at Full Moon phase of neutral correlation.
#
# (Emilio Kiryakos)

# %% [markdown]
# An interesting theory that we would like to test is that stocks during new moons exhibit higher returns than those during full moon periods (https://personal.lse.ac.uk/yuan/papers/lunar.pdf). We are testing this theory for the years of 2021-2023.
#
# We are using the built in function .pct_change(), which calculates the difference in closing price from the previous day to the next. On top of that, we also calculate each stock's average returns from for each year. Provided are the relevant visualizations for each stock's returns on full and new moon periods from 2021-2023 in the order of APPL, NSDQ, NVDA, SPY, TSLA.
# ![Stock Volume vs Moon Phases](visualizations/apple_returns.png)
# ![Stock Volume vs Moon Phases](visualizations/nasdaq_returns.png)
# ![Stock Volume vs Moon Phases](visualizations/nvidia_returns.png)
# ![Stock Volume vs Moon Phases](visualizations/spy_returns.png)
# ![Stock Volume vs Moon Phases](visualizations/tesla_returns.png)

# %% [markdown]
# We found that that theory is confirmed mostly. Every stock except SPY, differently, had mostly had better returns during new moon periods. However, the way that we are doing this is currently flawed, as we are only looking at the closing prices during said period. Maybe we can use the opening prices as well as the closing prices, and find the differences of each day. Or take the difference of the stock closing price at the full moon and the stock at the new moon, and vice versa.
#
# (David Mendoza)
# **ML Analyses**
# ________________________________________________________________________________________________________________
# At least two ML analyses on your dataset, along with a baseline comparison and an
# interpretation of the result that you obtain. Write the name of the member(s) who is
# responsible for it while explaining it.

# %% [markdown]
# **(Adithya Jose) ML analysis on the Correlation between Tesla stock and Lunar Phases, sepcifically new moons and full moons.**
#
#  ________________________________________________________________________________________________________________
#
#  Interesting insights are revealed by comparing the performance of Tesla stocks with moon phases using machine learning techniques. Although there is some predictive potential in baseline linear regression models, the performance of the models is only slightly improved by including moon phases. The results of correlation analysis point to a small but noticeable relationship, suggesting potential directions for future research at the relationship of money and astronomical events.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It is clear from the analysis of the correlation between Tesla stock prices and lunar phases that the two variables have a favorable relationship. The scatter plot with the blue line indicates that there is a pattern for Tesla stock prices to move in parallel with changes in moon phases. It's crucial to remember that the relationship is nonlinear, suggesting that additional factors might possibly have an impact on stock prices. In summary, this analysis indicates a strong relation between Tesla stock prices and lunar phases; however, additional research is needed to fully comprehend the nature of this link.

# %% [markdown]
# **(Mustafa Ausaf) "Exploring Correlations Between Moon Phases and Apple Stock Trends with Random Forest Classification and Data Visualization"**

# %% [markdown]
# ![Stock Volume vs Moon Phases](visualizations/mustafa_6.png)
#
#
#
# + The bar chart shows a clear visual comparison between the two phases. Prices change more in the Last Quarter.
#
# + Further analysis and statistical modeling would be required to determine any meaningful relationship between the two variables other than the closing price decreasing as the phases go by.

# %% [markdown]
# ![Stock Volume vs Moon Phases](visualizations/mustafa_3.png)
#
#
#
#
# - This chart assesses the average daily price change (closing price minus opening price) associated with each moon phase.
#
# - By visualizing the average price change for each phase, the chart seeks to reveal whether certain moon phases are associated with more volatile or stable trading days.
#
# - A positive average suggests prices tend to rise during the day, while a negative average indicates a decline.

# %% [markdown]
# ![Stock Volume vs Moon Phases](visualizations/mustafa_5.png)
#
#
# - This line chart depicts the average closing price of Apple stock for each moon phase, similar to the bar chart.
#
# - However, it represents the data as a continuous line connecting the points for each moon phase, which can help in observing trends or patterns more clearly.
#
#
# - Each point on the line represents the average closing price for a particular moon phase, with lines connecting these points to illustrate progression or trends across phases.
#
# - This can help identify cyclical patterns in stock prices relative to the lunar cycle.

# %% [markdown]
# **The charts above seem to depict the average closing price of Apple stock based on different lunar phases, specifically the "New Moon" and "Full Moon."**
#
# **The bar chart format allows for a clear visual comparison between the two phases. Prices change more in the Last Quarter. Further analysis and statistical modeling would be required to determine any meaningful relationship between the two variables other than the closing price decreasing as the phases go by.**

# %% [markdown]
# **Mustafa Ausaf ML Reflection:**
# ________________________________________________________________________________________________________________
# - ○ What is the most challenging part of the project that you’ve encountered so far?
#
#     - The most challenging aspect of this project was undoubtedly the data integration and preprocessing. Aligning data from two very different sources (moon phases and stock prices) into a coherent, usable format required careful handling to ensure accurate timestamp matching and integrity of the data. Additionally, determining how best to structure the data for ML purposes, such as deciding which features to include and how to handle anomalies, proved to be intricate tasks that required both time and meticulousness.
#
#
# - ○ What are your initial insights?
#
#     - Early insights from the analysis were quite intriguing. Despite a common perception that celestial events might influence human behavior and potentially financial markets, initial results suggested that the relationship between moon phases and stock prices might not be as clear-cut or as significant as folklore or initial hypotheses would suggest. The variability in stock prices appears to be influenced by a myriad of factors, of which moon phases might only be a marginal or coincidental factor.
#
#
# - ○ Are there any concrete results you can show at this point? If not, why not?
#
#     - At this point, the concrete results include the successful training of a RandomForestClassifier which achieved an accuracy higher than the baseline model. This suggests some level of learning beyond mere chance, although the practical significance of this in a trading strategy context remains debatable. The visualizations created also provide a clear depiction of how stock prices fluctuate across different moon phases but do not suggest a reliable pattern that could be exploited predictively with high confidence.
#
#
# - ○ Going forward, what are the current biggest problems you’re facing?
#
#     - Moving forward, the primary challenges include enhancing the model’s predictive accuracy and determining if the patterns observed are statistically significant or could be attributed to random fluctuations. There's also the challenge of addressing overfitting despite the current model's robustness against it, and improving the model's generalizability to other stocks or broader market indices.
#
#
# - ○ Do you think you are on track with your project? If not, what parts do you need to
# dedicate more time to?
#     - I believe the project is on the right track, particularly in terms of exploring an unconventional dataset and hypothesis. However, more time needs to be dedicated to refining the ML model and exploring additional features that could provide deeper insights. Advanced techniques like feature selection, hyperparameter tuning, and cross-validation need to be implemented to enhance model performance and reliability.
#
#
# - ○ Given your initial exploration of the data, is it worth proceeding with your project,
# why? If not, how will you move forward (method, data etc)?
#
#     - Given the initial exploration, continuing with this project seems worthwhile primarily for its academic and exploratory value. Even if the ultimate results suggest that moon phases have limited predictive power regarding stock movements, the process provides valuable insights into the complexities of financial data modeling and the limits of what can be predicted. If results continue to show limited practical applications, the focus could shift towards a more robust analysis involving different stocks, larger datasets, or integrating additional variables like geopolitical events or macroeconomic indicators that might show stronger correlations and predictive capabilities.

# %% [markdown]
# **Next Steps:**
# ________________________________________________________________________________________________________________
# The next steps in our reseach and analyis would to be refine what we have already found and obtain more data to support
# or oppose our hypothesis. We would like to look at a variety of other stocks, and put more data into our ML model to
# train.
